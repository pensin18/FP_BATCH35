# %%
import yfinance as yf
data = yf.download('RELIANCE.NS',period='50d',interval='15m',multi_level_index=False,ignore_tz=True)
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                            Close         High          Low         Open  \
# Datetime
# 2025-12-04 09:15:00  1545.000000  1545.000000  1536.500000  1538.900024
# 2025-12-04 09:30:00  1547.300049  1547.900024  1543.400024  1544.900024
# 2025-12-04 09:45:00  1548.599976  1549.900024  1546.599976  1547.300049
# 2025-12-04 10:00:00  1550.800049  1551.000000  1548.199951  1548.599976
# 2025-12-04 10:15:00  1553.199951  1553.300049  1548.699951  1550.800049
# ...                          ...          ...          ...          ...
# 2026-02-13 14:15:00  1422.500000  1426.800049  1421.500000  1421.599976
# 2026-02-13 14:30:00  1419.500000  1423.800049  1419.000000  1423.000000
# 2026-02-13 14:45:00  1422.800049  1424.900024  1418.500000  1419.500000
# 2026-02-13 15:00:00  1418.900024  1423.000000  1418.199951  1422.800049
# 2026-02-13 15:15:00  1418.800049  1420.800049  1417.599976  1419.000000
#
# ...

# %%
data = yf.download('DOT-USD',period='7d',interval='1m',multi_level_index=False,ignore_tz=True)
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                         Close      High       Low      Open  Volume
# Datetime
# 2026-02-08 00:00:00  1.372244  1.372244  1.372244  1.372244       0
# 2026-02-08 00:01:00  1.371988  1.371988  1.371988  1.371988       0
# 2026-02-08 00:02:00  1.371916  1.371916  1.371916  1.371916    7056
# 2026-02-08 00:03:00  1.372043  1.372043  1.372043  1.372043       0
# 2026-02-08 00:04:00  1.371637  1.371637  1.371637  1.371637       0
# ...                       ...       ...       ...       ...     ...
# 2026-02-14 13:06:00  1.364058  1.364058  1.364058  1.364058   28080
# 2026-02-14 13:07:00  1.363620  1.363620  1.363620  1.363620   66584
# 2026-02-14 13:09:00  1.363842  1.363842  1.363842  1.363842       0
# 2026-02-14 13:10:00  1.364223  1.364223  1.364223  1.364223   73320
# 2026-02-14 13:12:00  1.364054  1.364054  1.364054  1.364054    7944
#
# [8206 rows x 5 columns]

# %%
stock = yf.Ticker('AMZN')
stock.info
# Out:
# {'address1': '410 Terry Avenue North',
#  'city': 'Seattle',
#  'state': 'WA',
#  'zip': '98109-5210',
#  'country': 'United States',
#  'phone': '206 266 1000',
#  'website': 'https://www.amazon.com',
#  'industry': 'Internet Retail',
#  'industryKey': 'internet-retail',
#  'industryDisp': 'Internet Retail',
#  'sector': 'Consumer Cyclical',
#  'sectorKey': 'consumer-cyclical',
#  'sectorDisp': 'Consumer Cyclical',
# ...

# %%
stock_name = ['AMZN','AAPL','GOOGL','MSFT','TSLA']
data1={}
for i in stock_name:
    stock = yf.Ticker(i)
    b=stock.info.get('beta')
    data1.update({i:b})
data1
# Out:
# {'AMZN': 1.385, 'AAPL': 1.107, 'GOOGL': 1.086, 'MSFT': 1.084, 'TSLA': 1.887}

# %%
c = list(data1.values())
stock_name = c.index(max(c))
stock_name
# Out:
# 4

# %%
stock.cash_flow
# Out:
#                                                   2025-12-31    2024-12-31  \
# Free Cash Flow                                  6.220000e+09  3.581000e+09
# Repayment Of Debt                              -5.650000e+09 -2.881000e+09
# Issuance Of Debt                                5.586000e+09  5.744000e+09
# Issuance Of Capital Stock                                NaN           NaN
# Capital Expenditure                            -8.527000e+09 -1.134200e+10
# Interest Paid Supplemental Data                 2.920000e+08  2.770000e+08
# Income Tax Paid Supplemental Data                        NaN  1.331000e+09
# End Cash Position                               1.761600e+10  1.703700e+10
# Beginning Cash Position                         1.703700e+10  1.718900e+10
# Effect Of Exchange Rate Changes                 1.710000e+08 -1.410000e+08
# Changes In Cash                                 4.080000e+08 -1.100000e+07
# ...

# %%
data = yf.download('DOT-USD',start='2026-01-01',end='2026-02-01',interval='1d',multi_level_index=False,ignore_tz=True)
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                Close      High       Low      Open     Volume
# Date
# 2026-01-01  1.996028  2.017035  1.764219  1.789186  223301764
# 2026-01-02  2.161198  2.161372  1.968370  1.996015  262707293
# 2026-01-03  2.125039  2.213410  2.111297  2.161165  182431908
# 2026-01-04  2.139850  2.177495  2.120168  2.125039  141622365
# 2026-01-05  2.208401  2.230329  2.097358  2.139852  229622369
# 2026-01-06  2.234120  2.256708  2.118593  2.208383  238295109
# 2026-01-07  2.143120  2.240258  2.122442  2.234095  163737516
# 2026-01-08  2.109905  2.153027  2.088949  2.143120  143541675
# 2026-01-09  2.080213  2.134063  2.052845  2.109928  136192247
# 2026-01-10  2.090097  2.126498  2.069250  2.080224   71589713
# 2026-01-11  2.066166  2.120471  2.040722  2.090083   80170064
# 2026-01-12  2.052330  2.146858  2.030260  2.066168  135923962
# 2026-01-13  2.281716  2.336015  2.051447  2.052330  299518636
# ...
