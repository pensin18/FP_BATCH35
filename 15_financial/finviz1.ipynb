# %%
! pip install finvizfinance
# Out:
# Collecting finvizfinance
#   Downloading finvizfinance-1.3.0-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: pandas in c:\users\75pen\fp_batch35\.venv\lib\site-packages (from finvizfinance) (2.3.3)
# Requirement already satisfied: requests in c:\users\75pen\fp_batch35\.venv\lib\site-packages (from finvizfinance) (2.32.5)
# Requirement already satisfied: beautifulsoup4 in c:\users\75pen\fp_batch35\.venv\lib\site-packages (from finvizfinance) (4.14.3)
# Collecting lxml (from finvizfinance)
#   Using cached lxml-6.0.2-cp312-cp312-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\75pen\fp_batch35\.venv\lib\site-packages (from beautifulsoup4->finvizfinance) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\75pen\fp_batch35\.venv\lib\site-packages (from beautifulsoup4->finvizfinance) (4.15.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\75pen\fp_batch35\.venv\lib\site-packages (from pandas->finvizfinance) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\75pen\fp_batch35\.venv\lib\site-packages (from pandas->finvizfinance) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\75pen\fp_batch35\.venv\lib\site-packages (from pandas->finvizfinance) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\75pen\fp_batch35\.venv\lib\site-packages (from pandas->finvizfinance) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\75pen\fp_batch35\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->finvizfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\75pen\fp_batch35\.venv\lib\site-packages (from requests->finvizfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\75pen\fp_batch35\.venv\lib\site-packages (from requests->finvizfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\75pen\fp_batch35\.venv\lib\site-packages (from requests->finvizfinance) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\75pen\fp_batch35\.venv\lib\site-packages (from requests->finvizfinance) (2026.1.4)
# Downloading finvizfinance-1.3.0-py3-none-any.whl (44 kB)
# Using cached lxml-6.0.2-cp312-cp312-win_amd64.whl (4.0 MB)
# Installing collected packages: lxml, finvizfinance
#
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    -------------------- ------------------- 1/2 [finvizfinance]
#    ---------------------------------------- 2/2 [finvizfinance]
#
# Successfully installed finvizfinance-1.3.0 lxml-6.0.2
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from finvizfinance.quote import finvizfinance
stock = finvizfinance('AMZN')
stock.ticker_fundament()
# Out:
# {'Company': 'Amazon.com Inc',
#  'Sector': 'Consumer Cyclical',
#  'Industry': 'Internet Retail',
#  'Country': 'USA',
#  'Exchange': 'NASD',
#  'Index': 'DJIA, NDX, S&P 500',
#  'P/E': '27.72',
#  'EPS (ttm)': '7.17',
#  'Insider Own': '9.40%',
#  'Shs Outstand': '10.73B',
#  'Perf Week': '-5.48%',
#  'Market Cap': '2133.99B',
#  'Forward P/E': '21.07',
#  'EPS next Y': '9.43',
#  'Insider Trans': '-0.02%',
#  'Shs Float': '9.73B',
#  'Perf Month': '-16.00%',
#  'Enterprise Value': '2177.60B',
#  'PEG': '1.14',
#  'EPS next Q': '1.62',
#  'Inst Own': '65.53%',
#  'Short Float': '0.74%',
#  'Perf Quarter': '-18.60%',
#  'Income': '77.67B',
#  'P/S': '2.98',
#  'EPS this Y': '8.31%',
#  'Inst Trans': '0.24%',
#  'Short Ratio': '1.54',
#  'Perf Half Y': '-13.94%',
#  'Sales': '716.92B',
#  'P/B': '5.19',
#  'EPS next Y Percentage': '21.49%',
#  'ROA': '10.77%',
#  'Short Interest': '71.85M',
#  'Perf YTD': '-13.88%',
#  'Book/sh': '38.31',
#  'P/C': '16.89',
#  'EPS next 5Y': '18.48%',
#  'ROE': '22.29%',
#  '52W High': '258.60 -23.13%',
#  'Perf Year': '-13.71%',
#  'Cash/sh': '11.77',
#  'P/FCF': '277.32',
#  'EPS past 3/5Y': '- 27.96%',
#  'ROIC': '13.77%',
#  '52W Low': '161.38 23.18%',
#  'Perf 3Y': '99.71%',
#  'Dividend Est.': '-',
#  'EV/EBITDA': '14.48',
#  'Sales past 3/5Y': '11.73% 13.18%',
#  'Gross Margin': '50.29%',
#  'Volatility W': '3.18%',
#  'Volatility M': '2.83%',
#  'Perf 5Y': '21.30%',
#  'Dividend TTM': '-',
#  'EV/Sales': '3.04',
#  'EPS Y/Y TTM': '28.97%',
#  'Oper. Margin': '11.80%',
#  'ATR (14)': '7.27',
#  'Perf 10Y': '684.06%',
#  'Dividend Ex-Date': '-',
#  'Quick Ratio': '0.88',
#  'Sales Y/Y TTM': '12.38%',
#  'Profit Margin': '10.83%',
#  'RSI (14)': '23.09',
#  'Recom': '1.28',
#  'Dividend Gr. 3/5Y': '- -',
#  'Current Ratio': '1.05',
#  'EPS Q/Q': '5.04%',
#  'SMA20': '-12.58%',
#  'Beta': '1.42',
#  'Target Price': '280.98',
#  'Payout': '0.00%',
#  'Debt/Eq': '0.41',
#  'Sales Q/Q': '13.63%',
#  'SMA50': '-13.74%',
#  'Rel Volume': '1.42',
#  'Prev Close': '199.60',
#  'Employees': '1576000',
#  'LT Debt/Eq': '0.37',
#  'Earnings': 'Feb 05 AMC',
#  'SMA200': '-11.10%',
#  'Avg Volume': '46.67M',
#  'Price': '198.79',
#  'IPO': 'May 15, 1997',
#  'Option/Short': 'Yes / Yes',
#  'EPS/Sales Surpr.': '-1.00% 0.92%',
#  'Trades': '\n\n',
#  'Volume': '66,114,306',
#  'Change': '-0.41%'}
